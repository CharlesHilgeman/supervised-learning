# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
### Preprocessing: Convert categorical data to numeric ###

# %%
train_df = pd.read_csv('Resources/2019loans.csv')
test_df = pd.read_csv('Resources/2020Q1loans.csv')
train_df = train_df.drop(columns=['Unnamed: 0'])
test_df = test_df.drop(columns=['Unnamed: 0'])

# %%
X_trainer = train_df.drop('loan_status', axis = 1)
X_tester = test_df.drop('loan_status', axis=1)

# %%
X_trainer_dummies = pd.get_dummies(X_trainer)
X_trainer_dummies = X_trainer_dummies.drop(columns=['debt_settlement_flag_Y'])
print(X_trainer_dummies.columns)
X_trainer_dummies
# Out:
# Index(['index', 'loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

y_train_label = LabelEncoder().fit_transform(train_df['loan_status'])
y_train_label
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
X_tester_dummies = pd.get_dummies(X_tester)
print(X_tester_dummies.columns)
X_tester_dummies
# Out:
# Index(['index', 'loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
y_test_label = LabelEncoder().fit_transform(test_df['loan_status'])
y_test_label
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
#X_train, X_test, y_train, y_test = train_test_split(X_dummies, y_label, random_state=1)

# %%
scaler = StandardScaler().fit(X_trainer_dummies)
X_train_scaled = scaler.transform(X_trainer_dummies)
X_test_scaled = scaler.transform(X_tester_dummies)

# %%
### Fit a LogisticRegression model and RandomForestClassifier model ###

# %% [markdown]
# Logistic Regression vs Random Forest Classifier:
#
# I think the Random Forest Classifier will perform better in this situation than Logistic Regression will. From what we've learned in class, over-fitting the data is a real possibility so if a training set with a particular amount of noise will cause the regression to sacrifice its testing score to "better" fit the training data. In this case, I think the Random Forest Classifier will likely ignore some of those to achieve a more accurate model.

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_trainer_dummies, y_train_label)
# Out:
# C:\Users\Charles Hilgeman\anaconda\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Logistic Regression")
print(f"Training Score: {classifier.score(X_trainer_dummies, y_train_label)}")
print(f"Testing Score: {classifier.score(X_tester_dummies, y_test_label)}")
# Out:
# Logistic Regression
# Training Score: 0.6576354679802956
# Testing Score: 0.5202041684389621

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

scaler = StandardScaler().fit(X_trainer_dummies)
X_train_scaled = scaler.transform(X_trainer_dummies)
X_test_scaled = scaler.transform(X_tester_dummies)

# %%
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train_label)
print("Random Forest Classifier")
print(f"Training Score: {clf.score(X_train_scaled, y_train_label)}")
print(f"Testing Score: {clf.score(X_test_scaled, y_test_label)}")
# Out:
# Random Forest Classifier
# Training Score: 1.0
# Testing Score: 0.6737558485750744

# %%
### Revisit the Preprocessing: Scale the data ###

# %%
features = clf.feature_importances_
plt.bar(x = range(len(features)), height=features)
# Out:
# <BarContainer object of 92 artists>

# %%
from sklearn.feature_selection import SelectFromModel

sel = SelectFromModel(clf)
sel.fit(X_train_scaled, y_train_label)
sel.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True, False, False, False,
#        False,  True, False,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True, False, False, False, False,  True,
#        False, False, False, False,  True,  True,  True, False, False,
#         True,  True,  True, False, False, False, False,  True,  True,
#         True, False, False,  True,  True,  True, False, False,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True,  True,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
#X_selected_train, X_selected_test, y_train, y_test = train_test_split(sel.transform(X_train_scaled), y_train, random_state=1)
X_selected_train = sel.transform(X_train_scaled)
X_selected_test = sel.transform(X_test_scaled)

scaler = StandardScaler().fit(X_selected_train)
X_selected_train_scaled = scaler.transform(X_selected_train)
X_selected_test_scaled = scaler.transform(X_selected_test)

# %%
clf = LogisticRegression()
clf.fit(X_selected_train_scaled, y_train_label)
print("Logistic Regression")
print(f"Training Score: {clf.score(X_selected_train_scaled, y_train_label)}")
print(f"Testing Score: {clf.score(X_selected_test_scaled, y_test_label)}")
# Out:
# Logistic Regression
# Training Score: 0.7069786535303777
# Testing Score: 0.7243726074011059
# C:\Users\Charles Hilgeman\anaconda\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_selected_train_scaled, y_train_label)
print("Random Forest Classifier")
print(f"Training Score: {clf.score(X_selected_train_scaled, y_train_label)}")
print(f"Testing Score: {clf.score(X_selected_test_scaled, y_test_label)}")
# Out:
# Random Forest Classifier
# Training Score: 1.0
# Testing Score: 0.6239897915780519

# %% [markdown]
# The results are much different than I expected. I expected that the Logistic Regression Method would overfit the data but it appears the Random Forest Classifier did. The training score is much higher and the testing score is much lower.
